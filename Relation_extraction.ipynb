# %% [markdown]
# # Relation extraction
# ## Table of contents<a name=contents></a>
# 0. [Downloads](#downloads)
# 1. [Packages](#packages)
# 2. [Text](#text)
# 3. [NLP pipes](#pipes)
# 4. [Dependency trees](#trees)
#
# ## 0. Downloads <a name=downloads></a>

# %%
import nltk
nltk.download('reuters')

# %%
# !unzip /root/nltk_data/corpora/reuters.zip -d /root/nltk_data/corpora

# %%
# !pip install -U spacy==3.0.7

# %%
# !python -m spacy download en_core_web_lg
# Out:
# /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0
# Collecting en-core-web-lg==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.2.0/en_core_web_lg-3.2.0-py3-none-any.whl (777.4 MB)
#      |████████████████████████████████| 777.4 MB 5.9 kB/s             ��████████▋   | 695.0 MB 19.3 MB/s eta 0:00:05 |███████████████████████████████ | 754.5 MB 1.6 MB/s eta 0:00:15
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from en-core-web-lg==3.2.0) (3.2.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (8.0.13)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.27.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.3.0)
# Requirement already satisfied: packaging>=20.0 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (21.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (0.9.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.8.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.0.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.21.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (0.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.0.8)
# Requirement already satisfied: jinja2 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.0.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (0.3.2)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.10.0.2)
# Requirement already satisfied: setuptools in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (60.5.0)
# Requirement already satisfied: pathy>=0.3.5 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (0.6.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.4.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (4.62.3)
# Requirement already satisfied: zipp>=0.5 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.0.6)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.0.10)
# Requirement already satisfied: idna<4,>=2.5 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (3.3)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/becode/anaconda3/envs/Algorythm/lib/python3.7/site-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-lg==3.2.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
# !python -m spacy download en_core_web_sm

# %%
# !pip install allennlp==2.1.0 allennlp-models==2.1.0

# %%
# !wget "https://storage.googleapis.com/allennlp-public-models/coref-spanbert-large-2021.03.10.tar.gz"

# %% [markdown]
# ## 1. Packages <a name=packages></a>

# %%
import spacy
from spacy import displacy


from spacy.tokens import Token
from spacy import Language

from collections import deque

from nltk.corpus import reuters

import regex as re

import requests
from bs4 import BeautifulSoup

import pandas as pd

#from allennlp.predictors.predictor import Predictor
#import allennlp_models.tagging # from allennlp_models.pretrained import load_predictor

# %% [markdown]
# ## 2. Text

# %%
nlp = spacy.load('en_core_web_lg')

# %%
text = "Fujitsu, a competitor of NEC, acquired Fairchild Corp."
doc = nlp(text)

# %%
displacy.render(doc, style="dep",options={'compact': False, 'distance': 100})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0f8a0c65bd5c44c9afe536e0fbbda0db-0" class="displacy" width="850" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Fujitsu,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">competitor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">NEC,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">acquired</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Fairchild</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Corp.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f8a0c65bd5c44c9afe536e0fbbda0db-0-0" stroke-width="2px" d="M70,152.0 C70,2.0 550.0,2.0 550.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0f8a0c65bd5c44c9afe536e0fbbda0db-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,154.0 L62,142.0 78,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f8a0c65bd5c44c9afe536e0fbbda0db-0-1" stroke-width="2px" d="M170,152.0 C170,102.0 240.0,102.0 240.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0f8a0c65bd5c44c9afe536e0fbbda0db-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,154.0 L162,142.0 178,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f8a0c65bd5c44c9afe536e0fbbda0db-0-2" stroke-width="2px" d="M70,152.0 C70,52.0 245.0,52.0 245.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0f8a0c65bd5c44c9afe536e0fbbda0db-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245.0,154.0 L253.0,142.0 237.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f8a0c65bd5c44c9afe536e0fbbda0db-0-3" stroke-width="2px" d="M270,152.0 C270,102.0 340.0,102.0 340.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0f8a0c65bd5c44c9afe536e0fbbda0db-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M340.0,154.0 L348.0,142.0 332.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f8a0c65bd5c44c9afe536e0fbbda0db-0-4" stroke-width="2px" d="M370,152.0 C370,102.0 440.0,102.0 440.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0f8a0c65bd5c44c9afe536e0fbbda0db-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M440.0,154.0 L448.0,142.0 432.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f8a0c65bd5c44c9afe536e0fbbda0db-0-5" stroke-width="2px" d="M670,152.0 C670,102.0 740.0,102.0 740.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0f8a0c65bd5c44c9afe536e0fbbda0db-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,154.0 L662,142.0 678,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0f8a0c65bd5c44c9afe536e0fbbda0db-0-6" stroke-width="2px" d="M570,152.0 C570,52.0 745.0,52.0 745.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0f8a0c65bd5c44c9afe536e0fbbda0db-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,154.0 L753.0,142.0 737.0,142.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# Back to the [table of contents](#contents).
#
# ## 3. NLP pipes <a name=pipes></a>

# %%
Token.set_extension('ref_n', default='', force = True)
Token.set_extension('ref_t', default='', force = True)

@Language.component("init_coref")
def init_coref(doc):
    for e in doc.ents:
        if e.label_ in ['ORG', 'GOV', 'PERSON','MONEY']:
            e[0]._.ref_n, e[0]._.ref_t = e.text, e.label_
    return doc

# %%
def reset_pipeline(nlp, pipes):
    # remove all custom pipes
    custom_pipes = [pipe for (pipe, _) in nlp.pipeline
                    if pipe not in ['tagger', 'parser', 'ner',
                                    'tok2vec', 'attribute_ruler', 'lemmatizer']]
    for pipe in custom_pipes:
        _ = nlp.remove_pipe(pipe)
    # re-add specified pipes
    for pipe in pipes:
        if 'neuralcoref' == pipe or 'neuralcoref' in str(pipe.__class__):
            nlp.add_pipe(pipe, name='neural_coref')
        else:
            nlp.add_pipe(pipe)

    print(f"Model: {nlp.meta['name']}, Language: {nlp.meta['lang']}")
    print(*nlp.pipeline, sep='\n')
    
reset_pipeline(nlp, ['init_coref'])
# Out:
# Model: core_web_lg, Language: en
# ('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec object at 0x7f7021248d00>)
# ('tagger', <spacy.pipeline.tagger.Tagger object at 0x7f7021248c90>)
# ('parser', <spacy.pipeline.dep_parser.DependencyParser object at 0x7f7020f2be50>)
# ('attribute_ruler', <spacy.pipeline.attributeruler.AttributeRuler object at 0x7f7020e2d960>)
# ('lemmatizer', <spacy.lang.en.lemmatizer.EnglishLemmatizer object at 0x7f7020ec4690>)
# ('ner', <spacy.pipeline.ner.EntityRecognizer object at 0x7f7020f2bed0>)
# ('init_coref', <function init_coref at 0x7f70211cb320>)

# %% [markdown]
# Back to the [table of contents](#contents).
#
# ## 4. Dependency trees <a name=trees></a>
#
# Dependency trees seem to be very efficient to find verbs (active or passive) and their subject and object.

# %%
# Actually we search for the shortest path between the
# subject running through our predicate (verb) to the object.
# subject and object are organizations in our examples.

# Here are the three helper functions omitted in the book:
# - bfs: breadth first searching the closest subject/object 
# - is_passive: checks if noun or verb is in passive form
# - find_subj: searches left part of tree for subject
# - find_obj: searches right part of tree for object

def bfs(root, ent_type: str, deps:list, first_dep_only=False):
    """
    
    : root: token containing the word at the left of the verb, hopefully the subject?
    : ent_type: specifies entity type (for now always called for "ORG")
    : deps: ??? ['nsubjpass', 'nsubj:pass'] ???
    : first_dep_only: 
    """
    """Return first child of root (included) that matches
    ent_type and dependency list by breadth first search.
    Search stops after first dependency match if first_dep_only
    (used for subject search - do not "jump" over subjects)"""
    # deque to ease the access to the list
    to_visit = deque([root]) # queue for bfs

    while len(to_visit) > 0:
        # the left element of the queue is given to child and deleted from the queue
        child = to_visit.popleft()
        ## print("child", child, child.dep_)
        # check if the dependency of the token was one of those provided
        if child.dep_ in deps:
            # check if the label/entity type is the same as the one provided
            if child._.ref_t == ent_type:
                return child
            #else:
            #    for 
            # explore what to do if we keep looking after the first dependency match?
            # quid for a subject with an "and"???
            elif first_dep_only: # first match (subjects)
                return None
        # check if it is a compound (adjective),
        # if the noun it describes dependency is one of those provided
        # and if it has the right entity type but only works on the first token of the entity (customized pipe)
        # why doesn't it return the whole entity then? A compound is no subject by its own...?
        # add " or child.head.head.dep_ in deps " to the second condition only if ent_type=="MONEY"
        # or use the root of the entity?
        elif child.dep_ == 'compound' and \
             (child.head.dep_ in deps or child.head.head.dep_ in deps) and \
             child._.ref_t == ent_type: # check if contained in compound
            return child
        to_visit.extend(list(child.children))
    return None

def is_passive(token):
    if token.dep_.endswith('pass'): # noun
        return True
    for left in token.lefts: # verb
        if left.dep_ == 'auxpass':
            return True
    return False

def find_subj(pred, ent_type: str, passive: bool):
    """
    Find closest subject in predicates left subtree or
    predicates parent's left subtree (recursive).
    Has a filter on organizations.
    : pred: token containing a verb
    : ent_type: specifies entity type (for now always called for "ORG")
    : passive: specifies if the verb is in the passive form
    : return: pred's subject
    """
    ## To modify to make it work for different kind of entities

    # begins with the further related word on the left of the predicate
    for left in pred.lefts:
        if passive: # if pred is passive, search for passive subject
            subj = bfs(left, ent_type, ['nsubjpass', 'nsubj:pass'], True)
        else:
            subj = bfs(left, ent_type, ['nsubj'], True)
        if subj is not None: # found it!
            return subj
    
    # if the subject is not on the left tree of the predicate,
    # the predicate's head could be another verb with the same subject
    # example: Apple is looking at buying a startup
    if pred.head != pred and not is_passive(pred): # why not just "passive" instead of is_passive(pred)?
        return find_subj(pred.head, ent_type, passive) # climb up left subtree
    else:
        return None

def find_obj(pred, ent_type, excl_prepos):
    """
    Find closest object in predicates right subtree.
    Skip prepositional objects if the preposition is in exclude list.
    Has a filter on organizations.
    : pred: token containing a verb
    : ent_type: specifies entity type (for now always called for "ORG")
    : excl_prepos: excluded prepositions
    : return: object of the predicate
    """
    
    ## To modify to make it work for different kind of entities
        
    # looks into every related token on the right of the predicate
    # until it finds an object filling the conditions
    for right in pred.rights:
        ## print("right: ",right)
        obj = bfs(right, ent_type, ['dobj', 'pobj', 'iobj', 'obj', 'obl'])
        # if an object is found,
        # it looks that its preposition is not excluded
        if obj is not None:
            if obj.dep_ == 'pobj' and obj.head.lemma_.lower() in excl_prepos: # check preposition
                continue
            return obj
    return None

def extract_rel_dep(doc, pred_name:str, pred_synonyms:str, excl_prepos=[]):
    """
    Method extracting relationship(s) (may be plural!)
    It only returns triplets!
    : doc: text to analyze
    : pred_name: predicate
    : pred_synonyms: predicate's synonyms
    : excl_prepos: prepositions which can not precede the object chosen
    : return: triplet(s) with the subject and its entity type,
              the predicate and the object and its entity type
    """
    for token in doc:
        ## print(token, token.pos_, token.lemma_)
        # looks for a verb equivalent to the predicate referred to
        if token.pos_ == 'VERB':# and token.lemma_ in pred_synonyms:
            ## print("found token: ",token)
            # saves that verb as a predicate (readability)
            # looks if it is passive
            # and then searches for the subject of the verb
            pred = token
            passive = is_passive(pred)
            ## print("passive: ",passive)
            subj = find_subj(pred, 'ORG', passive)
            ## print("subject: ",subj)
            # if the subject is found, it looks for the object
            if subj is not None:
                obj = find_obj(pred, 'MONEY', excl_prepos)
                ## print("object: ",obj)
                if obj is not None:
                    # if there is a subject and an object,
                    # it sets the triplet in the following order:
                    # active subject, verb in active form, passive subject
                    if passive: # switch roles
                        obj, subj = subj, obj
                    yield ((subj._.ref_n, subj._.ref_t), pred, #, pred_name
                           (obj._.ref_n, obj._.ref_t))

# %%
doc_pass = nlp("I have been married to my wife for 30 years")

# %%
for t in doc_pass:
    print(t,t.dep_,t.head)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_60809/3019628691.py in <module>
# ----> 1 for t in doc_pass:
#       2     print(t,t.dep_,t.head)
#
# NameError: name 'doc_pass' is not defined

# %%
doc_2verbs = nlp("Apple is looking at buying Amazon for 1 billion dlrs")

# %%
for elem in extract_rel_dep(doc_2verbs, pred_name="buy",pred_synonyms=["buy"]):
    print(elem)
# Out:
# found token:  buying
# passive:  False
# child Apple nsubj
# subject:  Apple
# right:  Amazon
# child Amazon dobj
# right:  for
# child for prep
# child dlrs pobj
# child billion nummod
# child 1 compound
# object:  1
# (('Apple', 'ORG'), 'buy', ('1 billion dlrs', 'MONEY'))

# %%
for t in doc_2verbs:
    print("TOKEN: ",t,"\ndepencies:",t.dep_,"\ntoken's head:", t.head)
    for child in t.children:
        print("children: \n",child)
    for left in t.lefts:
        print("lefts: \n",left)
    for right in t.rights:
        print("rights: \n",right)
# Out:
# TOKEN:  Apple
# depencies: nsubj
# token's head: looking
# TOKEN:  is
# depencies: aux
# token's head: looking
# TOKEN:  looking
# depencies: ROOT
# token's head: looking
# children:
#  Apple
# children:
#  is
# children:
#  at
# lefts:
#  Apple
# lefts:
#  is
# rights:
#  at
# TOKEN:  at
# depencies: prep
# token's head: looking
# children:
#  buying
# rights:
#  buying
# TOKEN:  buying
# depencies: pcomp
# token's head: at
# children:
#  Amazon
# children:
#  for
# rights:
#  Amazon
# rights:
#  for
# TOKEN:  Amazon
# depencies: dobj
# token's head: buying
# TOKEN:  for
# depencies: prep
# token's head: buying
# children:
#  billion
# rights:
#  billion
# TOKEN:  $
# depencies: quantmod
# token's head: billion
# TOKEN:  1
# depencies: compound
# token's head: billion
# TOKEN:  billion
# depencies: pobj
# token's head: for
# children:
#  $
# children:
#  1
# lefts:
#  $
# lefts:
#  1

# %%
doc_verb_before = nlp("If I eat an apple, I drink water")

# %%
type(doc_verb_before)
# Out:
# spacy.tokens.doc.Doc

# %%
def peek(iterable):
    try:
        first = next(iterable)
    except StopIteration:
        return None
    return iterable

# %%
for t in doc_verb_before:
    print("TOKEN: ",t,"\ntoken's head:", t.head)
    if peek(t.children):
        print("Children:")
        for child in t.children:
            print(child)
    if peek(t.lefts):
        print("Lefts:")
        for left in t.lefts:
            print(left)
    if peek(t.rights):
        print("Rights:")
        for right in t.rights:
            print(right)
    print("\n")
# Out:
# TOKEN:  If
# token's head: eat
#
#
# TOKEN:  I
# token's head: eat
#
#
# TOKEN:  eat
# token's head: drink
# Children:
# If
# I
# apple
# Lefts:
# If
# I
# Rights:
# apple
#
#
# TOKEN:  an
# token's head: apple
#
#
# TOKEN:  apple
# token's head: eat
# Children:
# an
# Lefts:
# an
#
#
# TOKEN:  ,
# token's head: drink
#
#
# TOKEN:  I
# token's head: drink
#
#
# TOKEN:  drink
# token's head: drink
# Children:
# eat
# ,
# I
# water
# Lefts:
# eat
# ,
# I
# Rights:
# water
#
#
# TOKEN:  water
# token's head: drink

# %%
next(doc_verb_before[2].children)
# Out:
# If

# %% [markdown]
# Back to the [table of contents](#contents).

# %%
reuters_fileids_crude = reuters.fileids(categories=['crude'])

# %%
reuters_fileids_crude[25]
# Out:
# 'test/16658'

# %%
article = reuters.raw(reuters_fileids_crude[1])

# %%
def clean(article:str):
    pattern = re.compile("\n")
    article = re.sub(pattern,"",article)
    pattern = re.compile(" +")
    article = re.sub(pattern," ",article)
    pattern = re.compile("(\s\&lt;.{1,4}>)")
    article = re.sub(pattern,"",article)
    # pattern = re.compile(".'s")
    # article = re.sub(pattern,"'s",article) #???
    article = article.strip()
    #re.findall("(\w[^\.]*\.)",article)
    return article

# %%
article = 'Cheap oil feedstocks, the weakened U.S. dollar and a plant utilization rate approaching 90 pct will propel the streamlined U.S. petrochemical industry to record profits this year, with growth expected through at least 1990, major company executives predicted. This bullish outlook for chemical manufacturing and an industrywide move to shed unrelated businesses has prompted GAF Corp &lt;GAF>, privately-held Cain Chemical Inc, and other firms to aggressively seek acquisitions of petrochemical plants. Oil companies such as Ashland Oil Inc &lt;ASH>, the Kentucky-based oil refiner and marketer, are also shopping for money-making petrochemical businesses to buy. "I see us poised at the threshold of a golden period," said Paul Oreffice, chairman of giant Dow Chemical Co &lt;DOW>, adding, "Ther\'s no major plant capacity being added around the world now. The whole game is bringing out new products and improving the old ones." Analysts say the chemical industr\'s biggest customers, automobile manufacturers and home builders that use a lot of paints and plastics, are expected to buy quantities this year. U.S. petrochemical plants are currently operating at about 90 pct capacity, reflecting tighter supply that could hike product prices by 30 to 40 pct this year, said John Dosher, managing director of Pace Consultants Inc of Houston. Demand for some products such as styrene could push profit margins up by as much as 300 pct, he said. Oreffice, speaking at a meeting of chemical engineers in Houston, said Dow would easily top the 741 mln dlrs it earned last year and predicted it would have the best year in its history. In 1985, when oil prices were still above 25 dlrs a barrel and chemical exports were adversely affected by the strong U.S. dollar, Dow had profits of 58 mln dlrs. "I believe the entire chemical industry is headed for a record year or close to it," Oreffice said. GAF chairman Samuel Heyman estimated that the U.S. chemical industry would report a 20 pct gain in profits during 1987. Last year, the domestic industry earned a total of 13 billion dlrs, a 54 pct leap from 1985. The turn in the fortunes of the once-sickly chemical industry has been brought about by a combination of luck and planning, said Pac\'s John Dosher. Dosher said last yea\'s fall in oil prices made feedstocks dramatically cheaper and at the same time the American dollar was weakening against foreign currencies. That helped boost U.S. chemical exports. Also helping to bring supply and demand into balance has been the gradual market absorption of the extra chemical manufacturing capacity created by Middle Eastern oil producers in the early 1980s. Finally, virtually all major U.S. chemical manufacturers have embarked on an extensive corporate restructuring program to mothball inefficient plants, trim the payroll and eliminate unrelated businesses. The restructuring touched off a flurry of friendly and hostile takeover attempts. GAF, which made an unsuccessful attempt in 1985 to acquire Union Carbide Corp &lt;UK>, recently offered three billion dlrs for Borg Warner Corp &lt;BOR>, a Chicago manufacturer of plastics and chemicals. Another industry powerhouse, W.R. Grace &lt;GRA> has divested its retailing, restaurant and fertilizer businesses to raise cash for chemical acquisitions. But some experts worry that the chemical industry may be headed for trouble if companies continue turning their back on the manufacturing of staple petrochemical commodities, such as ethylene, in favor of more profitable specialty chemicals that are custom-designed for a small group of buyers. "Companies like DuPont &lt;DD> and Monsanto Co &lt;MTC> spent the past two or three years trying to get out of the commodity chemical business in reaction to how badly the market had deteriorated," Dosher said. "But I think they will eventually kill the margins on the profitable chemicals in the niche market." Some top chemical executives share the concern. "The challenge for our industry is to keep from getting carried away and repeating past mistakes," GA\'s Heyman cautioned. "The shift from commodity chemicals may be ill-advised. Specialty businesses do not stay special long." Houston-based Cain Chemical, created this month by the Sterling investment banking group, believes it can generate 700 mln dlrs in annual sales by bucking the industry trend. Chairman Gordon Cain, who previously led a leveraged buyout of Dupon\'s Conoco In\'s chemical business, has spent 1.1 billion dlrs since January to buy seven petrochemical plants along the Texas Gulf Coast. The plants produce only basic commodity petrochemicals that are the building blocks of specialty products. "This kind of commodity chemical business will never be a glamorous, high-margin business," Cain said, adding that demand is expected to grow by about three pct annually. Garo Armen, an analyst with Dean Witter Reynolds, said chemical makers have also benefitted by increasing demand for plastics as prices become more competitive with aluminum, wood and steel products. Armen estimated the upturn in the chemical business could last as long as four or five years, provided the U.S. economy continues its modest rate of growth.'
cleaned_article = clean(article)

# %%
cleaned_article
# Out:
# 'Cheap oil feedstocks, the weakened U.S. dollar and a plant utilization rate approaching 90 pct will propel the streamlined U.S. petrochemical industry to record profits this year, with growth expected through at least 1990, major company executives predicted. This bullish outlook for chemical manufacturing and an industrywide move to shed unrelated businesses has prompted GAF Corp, privately-held Cain Chemical Inc, and other firms to aggressively seek acquisitions of petrochemical plants. Oil companies such as Ashland Oil Inc, the Kentucky-based oil refiner and marketer, are also shopping for money-making petrochemical businesses to buy. "I see us poised at the threshold of a golden period," said Paul Oreffice, chairman of giant Dow Chemical Co, adding, "Ther\'s no major plant capacity being added around the world now. The whole game is bringing out new products and improving the old ones." Analysts say the chemical industr\'s biggest customers, automobile manufacturers and home builders that use a lot of paints and plastics, are expected to buy quantities this year. U.S. petrochemical plants are currently operating at about 90 pct capacity, reflecting tighter supply that could hike product prices by 30 to 40 pct this year, said John Dosher, managing director of Pace Consultants Inc of Houston. Demand for some products such as styrene could push profit margins up by as much as 300 pct, he said. Oreffice, speaking at a meeting of chemical engineers in Houston, said Dow would easily top the 741 mln dlrs it earned last year and predicted it would have the best year in its history. In 1985, when oil prices were still above 25 dlrs a barrel and chemical exports were adversely affected by the strong U.S. dollar, Dow had profits of 58 mln dlrs. "I believe the entire chemical industry is headed for a record year or close to it," Oreffice said. GAF chairman Samuel Heyman estimated that the U.S. chemical industry would report a 20 pct gain in profits during 1987. Last year, the domestic industry earned a total of 13 billion dlrs, a 54 pct leap from 1985. The turn in the fortunes of the once-sickly chemical industry has been brought about by a combination of luck and planning, said Pac\'s John Dosher. Dosher said last yea\'s fall in oil prices made feedstocks dramatically cheaper and at the same time the American dollar was weakening against foreign currencies. That helped boost U.S. chemical exports. Also helping to bring supply and demand into balance has been the gradual market absorption of the extra chemical manufacturing capacity created by Middle Eastern oil producers in the early 1980s. Finally, virtually all major U.S. chemical manufacturers have embarked on an extensive corporate restructuring program to mothball inefficient plants, trim the payroll and eliminate unrelated businesses. The restructuring touched off a flurry of friendly and hostile takeover attempts. GAF, which made an unsuccessful attempt in 1985 to acquire Union Carbide Corp, recently offered three billion dlrs for Borg Warner Corp, a Chicago manufacturer of plastics and chemicals. Another industry powerhouse, W.R. Grace has divested its retailing, restaurant and fertilizer businesses to raise cash for chemical acquisitions. But some experts worry that the chemical industry may be headed for trouble if companies continue turning their back on the manufacturing of staple petrochemical commodities, such as ethylene, in favor of more profitable specialty chemicals that are custom-designed for a small group of buyers. "Companies like DuPont and Monsanto Co spent the past two or three years trying to get out of the commodity chemical business in reaction to how badly the market had deteriorated," Dosher said. "But I think they will eventually kill the margins on the profitable chemicals in the niche market." Some top chemical executives share the concern. "The challenge for our industry is to keep from getting carried away and repeating past mistakes," GA\'s Heyman ...

# %%
#predictor.predict(cleaned_article)
#coref_article = predictor.coref_resolved(cleaned_article)

# %%
for sent in reuters.sents(reuters_fileids_crude[1])[0:3]:
  print(sent)
# Out:
# ['ENERGY', '/', 'U', '.', 'S', '.']
# ['PETROCHEMICAL', 'INDUSTRY', 'Cheap', 'oil', 'feedstocks', ',', 'the', 'weakened', 'U', '.', 'S', '.', 'dollar', 'and', 'a', 'plant', 'utilization', 'rate', 'approaching', '90', 'pct', 'will', 'propel', 'the', 'streamlined', 'U', '.', 'S', '.', 'petrochemical', 'industry', 'to', 'record', 'profits', 'this', 'year', ',', 'with', 'growth', 'expected', 'through', 'at', 'least', '1990', ',', 'major', 'company', 'executives', 'predicted', '.']
# ['This', 'bullish', 'outlook', 'for', 'chemical', 'manufacturing', 'and', 'an', 'industrywide', 'move', 'to', 'shed', 'unrelated', 'businesses', 'has', 'prompted', 'GAF', 'Corp', '&', 'lt', ';', 'GAF', '>,', 'privately', '-', 'held', 'Cain', 'Chemical', 'Inc', ',', 'and', 'other', 'firms', 'to', 'aggressively', 'seek', 'acquisitions', 'of', 'petrochemical', 'plants', '.']

# %%
coref_article
# Out:
# 'Cheap oil feedstocks, the weakened U.S. dollar and a plant utilization rate approaching 90 pct will propel the streamlined U.S. petrochemical industry to record profits this year, with growth expected through at least 1990, major company executives predicted. This bullish outlook for chemical manufacturing and an industrywide move to shed unrelated businesses has prompted GAF Corp, privately-held Cain Chemical Inc, and other firms to aggressively seek acquisitions of petrochemical plants. Oil companies such as Ashland Oil Inc, the Kentucky-based oil refiner and marketer, are also shopping for money-making petrochemical businesses to buy. "I see the streamlined U.S. petrochemical industry poised at the threshold of a golden period," said I, adding, "Ther\'s no major plant capacity being added around the world now. The whole game is bringing out new products and improving the old ones." Analysts say the streamlined U.S. petrochemical industry\'s biggest customers, automobile manufacturers and home builders that use a lot of paints and plastics, are expected to buy quantities this year. U.S. petrochemical plants are currently operating at about 90 pct capacity, reflecting tighter supply that could hike product prices by 30 to 40 pct this year, said John Dosher, managing director of Pace Consultants Inc of Houston. Demand for some products such as styrene could push profit margins up by as much as 300 pct, John Dosher, managing director of Pace Consultants Inc of Houston said. I Houstonsaid the streamlined U.S. petrochemical industry would easily top the 741 mln dlrs the streamlined U.S. petrochemical industry earned last year and predicted the streamlined U.S. petrochemical industry would have the best year in the streamlined U.S. petrochemical industry\'s history. In 1985, when oil prices were still above 25 dlrs a barrel and chemical exports were adversely affected by the weakened U.S. dollar, the streamlined U.S. petrochemical industry had profits of 58 mln dlrs. "I believe the streamlined U.S. petrochemical industry is headed for a record year or close to a record year," I said. GAF Corp chairman Samuel Heyman estimated that the streamlined U.S. petrochemical industry would report a 20 pct gain in profits during this year. last year, the domestic industry earned a total of 13 billion dlrs, a 54 pct leap from 1985, when oil prices were still above 25 dlrs a barrel and chemical exports were adversely affected by the strong U.S. dollar. The turn in the fortunes of the streamlined U.S. petrochemical industry has been brought about by a combination of luck and planning, said Pac\'s John Dosher. Pac\'s John Dosher said last year\'s fall in oil prices made feedstocks dramatically cheaper and at the same time the weakened U.S. dollar was weakening against foreign currencies. That helped boost U.S. chemical exports. Also helping to bring supply and demand into balance has been the gradual market absorption of the extra chemical manufacturing capacity created by Middle Eastern oil producers in the early 1980s. Finally, virtually all major U.S. chemical manufacturers have embarked on an extensive corporate restructuring program to mothball inefficient plants, trim the payroll and eliminate unrelated businesses. an extensive corporate restructuring program to mothball inefficient plants, trim the payroll and eliminate unrelated businesses touched off a flurry of friendly and hostile takeover attempts. GAF Corp 1985, when oil prices were still above 25 dlrs a barrel and chemical exports were adversely affected by the strong U.S. dollar recently offered three billion dlrs for Borg Warner Corp, a Chicago manufacturer of plastics and chemicals. Another industry powerhouse, W.R. Grace has divested Another industry powerhouse, W.R. Grace\'s retailing, restaurant and fertilizer businesses to raise cash for chemical acquisitions. But some experts worry that the streamlined U.S. petrochemical industry may be headed for trouble if companies conti ...

# %%
doc_reuters = nlp(cleaned_article)

# %%
doc_reuters.text
# Out:
# 'Cheap oil feedstocks, the weakened U.S. dollar and a plant utilization rate approaching 90 pct will propel the streamlined U.S. petrochemical industry to record profits this year, with growth expected through at least 1990, major company executives predicted. This bullish outlook for chemical manufacturing and an industrywide move to shed unrelated businesses has prompted GAF Corp, privately-held Cain Chemical Inc, and other firms to aggressively seek acquisitions of petrochemical plants. Oil companies such as Ashland Oil Inc, the Kentucky-based oil refiner and marketer, are also shopping for money-making petrochemical businesses to buy. "I see us poised at the threshold of a golden period," said Paul Oreffice, chairman of giant Dow Chemical Co, adding, "Ther\'s no major plant capacity being added around the world now. The whole game is bringing out new products and improving the old ones." Analysts say the chemical industr\'s biggest customers, automobile manufacturers and home builders that use a lot of paints and plastics, are expected to buy quantities this year. U.S. petrochemical plants are currently operating at about 90 pct capacity, reflecting tighter supply that could hike product prices by 30 to 40 pct this year, said John Dosher, managing director of Pace Consultants Inc of Houston. Demand for some products such as styrene could push profit margins up by as much as 300 pct, he said. Oreffice, speaking at a meeting of chemical engineers in Houston, said Dow would easily top the 741 mln dlrs it earned last year and predicted it would have the best year in its history. In 1985, when oil prices were still above 25 dlrs a barrel and chemical exports were adversely affected by the strong U.S. dollar, Dow had profits of 58 mln dlrs. "I believe the entire chemical industry is headed for a record year or close to it," Oreffice said. GAF chairman Samuel Heyman estimated that the U.S. chemical industry would report a 20 pct gain in profits during 1987. Last year, the domestic industry earned a total of 13 billion dlrs, a 54 pct leap from 1985. The turn in the fortunes of the once-sickly chemical industry has been brought about by a combination of luck and planning, said Pac\'s John Dosher. Dosher said last yea\'s fall in oil prices made feedstocks dramatically cheaper and at the same time the American dollar was weakening against foreign currencies. That helped boost U.S. chemical exports. Also helping to bring supply and demand into balance has been the gradual market absorption of the extra chemical manufacturing capacity created by Middle Eastern oil producers in the early 1980s. Finally, virtually all major U.S. chemical manufacturers have embarked on an extensive corporate restructuring program to mothball inefficient plants, trim the payroll and eliminate unrelated businesses. The restructuring touched off a flurry of friendly and hostile takeover attempts. GAF, which made an unsuccessful attempt in 1985 to acquire Union Carbide Corp, recently offered three billion dlrs for Borg Warner Corp, a Chicago manufacturer of plastics and chemicals. Another industry powerhouse, W.R. Grace has divested its retailing, restaurant and fertilizer businesses to raise cash for chemical acquisitions. But some experts worry that the chemical industry may be headed for trouble if companies continue turning their back on the manufacturing of staple petrochemical commodities, such as ethylene, in favor of more profitable specialty chemicals that are custom-designed for a small group of buyers. "Companies like DuPont and Monsanto Co spent the past two or three years trying to get out of the commodity chemical business in reaction to how badly the market had deteriorated," Dosher said. "But I think they will eventually kill the margins on the profitable chemicals in the niche market." Some top chemical executives share the concern. "The challenge for our industry is to keep from getting carried away and repeating past mistakes," GA\'s Heyman ...

# %%
displacy.render(doc_reuters, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Cheap oil feedstocks, the weakened
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  dollar and a plant utilization rate approaching
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     90
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  pct will propel the streamlined
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  petrochemical industry to record profits
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , with growth expected through
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     at least 1990
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , major company executives predicted. This bullish outlook for chemical manufacturing and an industrywide move to shed unrelated businesses has prompted
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GAF Corp
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , privately-held
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cain Chemical Inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and other firms to aggressively seek acquisitions of petrochemical plants. Oil companies such as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ashland Oil Inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kentucky
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -based oil refiner and marketer, are also shopping for money-making petrochemical businesses to buy. &quot;I see us poised at the threshold of a golden period,&quot; said
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paul Oreffice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , chairman of giant
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dow Chemical Co
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , adding, &quot;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ther
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's no major plant capacity being added around the world now. The whole game is bringing out new products and improving the old ones.&quot; Analysts say the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chemical
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  industr's biggest customers, automobile manufacturers and home builders that use a lot of paints and plastics, are expected to buy quantities
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  petrochemical plants are currently operating at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 90
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  pct capacity, reflecting tighter supply that could hike product prices by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30 to 40
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  pct
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , said
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     John Dosher
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , managing director of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pace Consultants Inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Houston
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . Demand for some products such as styrene could push profit margins up by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     as much as 300
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</spa

# %%
for ent in doc_reuters.ents:
    if ent.label_ == "MONEY":#"CARDINAl": #"QUANTITY":
        print(ent)
# Out:
# 741 mln dlrs
# 58 mln dlrs
# 13 billion dlrs
# three billion dlrs
# 700 mln dlrs
# 1.1 billion dlrs

# %%
def synonyms(term):
    """
    source: https://stackoverflow.com/questions/52910297/pydictionary-word-has-no-synonyms-in-the-api
    """
    response = requests.get('https://www.thesaurus.com/browse/{}'.format(term))
    soup = BeautifulSoup(response.text, 'html.parser')
    soup.find('section', {'class': 'css-191l5o0-ClassicContentCard e1qo4u830'})
    return [span.text.strip() for span in soup.findAll('a', {'class': 'css-1kg1yv8 eh475bn0'})]

# %%
verb = "offer"
if peek(extract_rel_dep(sent, pred_name=verb, pred_synonyms=[verb]+synonyms(verb), excl_prepos=[])):
    for relation in extract_rel_dep(sent, pred_name=verb, pred_synonyms=[verb]+synonyms(verb), excl_prepos=[]):
        print(relation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5565/1976441973.py in <module>
#       1 verb = "offer"
# ----> 2 if peek(extract_rel_dep(sent, pred_name=verb, pred_synonyms=[verb]+synonyms(verb), excl_prepos=[])):
#       3     for relation in extract_rel_dep(sent, pred_name=verb, pred_synonyms=[verb]+synonyms(verb), excl_prepos=[]):
#       4         print(relation)
#
# NameError: name 'sent' is not defined

# %%
coref_article = 'Cheap oil feedstocks, the weakened U.S. dollar and a plant utilization rate approaching 90 pct will propel the streamlined U.S. petrochemical industry to record profits this year, with growth expected through at least 1990, major company executives predicted. This bullish outlook for chemical manufacturing and an industrywide move to shed unrelated businesses has prompted GAF Corp, privately-held Cain Chemical Inc, and other firms to aggressively seek acquisitions of petrochemical plants. Oil companies such as Ashland Oil Inc, the Kentucky-based oil refiner and marketer, are also shopping for money-making petrochemical businesses to buy. "I see us poised at the threshold of a golden period," said Paul Oreffice, chairman of giant Dow Chemical Co, adding, "Ther\'s no major plant capacity being added around the world now. The whole game is bringing out new products and improving the old ones." Analysts say the chemical industr\'s biggest customers, automobile manufacturers and home builders that use a lot of paints and plastics, are expected to buy quantities this year. U.S. petrochemical plants are currently operating at about 90 pct capacity, reflecting tighter supply that could hike product prices by 30 to 40 pct this year, said John Dosher, managing director of Pace Consultants Inc of Houston. Demand for some products such as styrene could push profit margins up by as much as 300 pct, John Dosher, managing director of Pace Consultants Inc of Houston said. Oreffice, speaking at a meeting of chemical engineers in Houston, said Dow would easily top the 741 mln dlrs Dow earned last year and predicted Dow would have the best year in Dow history. In 1985, when oil prices were still above 25 dlrs a barrel and chemical exports were adversely affected by the strong U.S. dollar, Dow had profits of 58 mln dlrs. "I believe the entire chemical industry is headed for a record year or close to the entire chemical industry," Oreffice said. GAF chairman Samuel Heyman estimated that the entire chemical industry would report a 20 pct gain in profits during 1987. last year, the entire chemical industry earned a total of 13 billion dlrs, a 54 pct leap from 1985. The turn in the fortunes of the entire chemical industry has been brought about by a combination of luck and planning, said Pac\'s John Dosher. Pac\'s John Dosher said last yea\'s fall in oil prices made feedstocks dramatically cheaper and at the same time the strong U.S. dollar was weakening against foreign currencies. That helped boost U.S. chemical exports. Also helping to bring supply and demand into balance has been the gradual market absorption of the extra chemical manufacturing capacity created by Middle Eastern oil producers in the early 1980s. Finally, virtually all major U.S. chemical manufacturers have embarked on an extensive corporate restructuring program to mothball inefficient plants, trim the payroll and eliminate unrelated businesses. The restructuring touched off a flurry of friendly and hostile takeover attempts. GAF, which made an unsuccessful attempt in 1985 to acquire Union Carbide Corp, recently offered three billion dlrs for Borg Warner Corp, a Chicago manufacturer of plastics and chemicals. Another industry powerhouse, W.R. Grace has divested W.R. Grace retailing, restaurant and fertilizer businesses to raise cash for chemical acquisitions. But some experts worry that the chemical industry may be headed for trouble if companies continue turning companies back on the manufacturing of staple petrochemical commodities, such as ethylene, in favor of more profitable specialty chemicals that are custom-designed for a small group of buyers. "Companies like DuPont and Monsanto Co spent the past two or three years trying to get out of the commodity chemical business in reaction to how badly the market had deteriorated," Dosher said. "But I think Companies like DuPont and Monsanto Co will eventually kill the margins on the profitable chemicals in the market." Some top chemical executives share the concern. "The challenge for the chemical industry is to keep from getting carried away and repeating past mistakes," GA\'s Heyman cautioned. "The shift from commodity chemicals may be ill-advised. Specialty businesses do not stay special long." Houston-based Cain Chemical, created this month by the Sterling investment banking group, believes the Sterling investment banking group can generate 700 mln dlrs in annual sales by bucking the industry trend. Chairman Gordon Cain, who previously led a leveraged buyout of Dupon\'s Conoco In\'s chemical business, has spent 1.1 billion dlrs since January to buy seven petrochemical plants along the Texas Gulf Coast. seven petrochemical plants along the Texas Gulf Coast produce only basic commodity petrochemicals that are the building blocks of specialty products. "This kind of commodity chemical business will never be a glamorous, high-margin business," Cain said, adding that demand is expected to grow by about three pct annually. Armen, said chemical makers have also benefitted by increasing demand for plastics as prices become more competitive with aluminum, wood and steel products. Armen estimated the upturn in the chemical business could last as long as four or five years, provided the U.S. economy continues the U.S. economy modest rate of growth.'

# %%
coref_article
# Out:
# 'Cheap oil feedstocks, the weakened U.S. dollar and a plant utilization rate approaching 90 pct will propel the streamlined U.S. petrochemical industry to record profits this year, with growth expected through at least 1990, major company executives predicted. This bullish outlook for chemical manufacturing and an industrywide move to shed unrelated businesses has prompted GAF Corp, privately-held Cain Chemical Inc, and other firms to aggressively seek acquisitions of petrochemical plants. Oil companies such as Ashland Oil Inc, the Kentucky-based oil refiner and marketer, are also shopping for money-making petrochemical businesses to buy. "I see us poised at the threshold of a golden period," said Paul Oreffice, chairman of giant Dow Chemical Co, adding, "Ther\'s no major plant capacity being added around the world now. The whole game is bringing out new products and improving the old ones." Analysts say the chemical industr\'s biggest customers, automobile manufacturers and home builders that use a lot of paints and plastics, are expected to buy quantities this year. U.S. petrochemical plants are currently operating at about 90 pct capacity, reflecting tighter supply that could hike product prices by 30 to 40 pct this year, said John Dosher, managing director of Pace Consultants Inc of Houston. Demand for some products such as styrene could push profit margins up by as much as 300 pct, John Dosher, managing director of Pace Consultants Inc of Houston said. Oreffice, speaking at a meeting of chemical engineers in Houston, said Dow would easily top the 741 mln dlrs Dow earned last year and predicted Dow would have the best year in Dow history. In 1985, when oil prices were still above 25 dlrs a barrel and chemical exports were adversely affected by the strong U.S. dollar, Dow had profits of 58 mln dlrs. "I believe the entire chemical industry is headed for a record year or close to the entire chemical industry," Oreffice said. GAF chairman Samuel Heyman estimated that the entire chemical industry would report a 20 pct gain in profits during 1987. last year, the entire chemical industry earned a total of 13 billion dlrs, a 54 pct leap from 1985. The turn in the fortunes of the entire chemical industry has been brought about by a combination of luck and planning, said Pac\'s John Dosher. Pac\'s John Dosher said last yea\'s fall in oil prices made feedstocks dramatically cheaper and at the same time the strong U.S. dollar was weakening against foreign currencies. That helped boost U.S. chemical exports. Also helping to bring supply and demand into balance has been the gradual market absorption of the extra chemical manufacturing capacity created by Middle Eastern oil producers in the early 1980s. Finally, virtually all major U.S. chemical manufacturers have embarked on an extensive corporate restructuring program to mothball inefficient plants, trim the payroll and eliminate unrelated businesses. The restructuring touched off a flurry of friendly and hostile takeover attempts. GAF, which made an unsuccessful attempt in 1985 to acquire Union Carbide Corp, recently offered three billion dlrs for Borg Warner Corp, a Chicago manufacturer of plastics and chemicals. Another industry powerhouse, W.R. Grace has divested W.R. Grace retailing, restaurant and fertilizer businesses to raise cash for chemical acquisitions. But some experts worry that the chemical industry may be headed for trouble if companies continue turning companies back on the manufacturing of staple petrochemical commodities, such as ethylene, in favor of more profitable specialty chemicals that are custom-designed for a small group of buyers. "Companies like DuPont and Monsanto Co spent the past two or three years trying to get out of the commodity chemical business in reaction to how badly the market had deteriorated," Dosher said. "But I think Companies like DuPont and Monsanto Co will eventually kill the margins on the profitable chemicals in the market." Some top ch ...

# %%
coref_doc = nlp(coref_article)

# %%
if peek(extract_rel_dep(coref_doc, pred_name=verb, pred_synonyms=[verb]+synonyms(verb), excl_prepos=[])):
    for relation in extract_rel_dep(coref_doc, pred_name=verb, pred_synonyms=[verb]+synonyms(verb), excl_prepos=[]):
        print(relation)
# Out:
# (('Dow', 'ORG'), top, ('Dow', 'ORG'))
# (('Dow', 'ORG'), predicted, ('Dow', 'ORG'))
# (('Dow', 'ORG'), have, ('Dow', 'ORG'))
# (('GAF', 'ORG'), made, ('Union Carbide Corp', 'ORG'))
# (('GAF', 'ORG'), acquire, ('Union Carbide Corp', 'ORG'))
# (('GAF', 'ORG'), offered, ('Borg Warner Corp', 'ORG'))

# %%
if peek(extract_rel_dep(coref_doc, pred_name=verb, pred_synonyms=[verb]+synonyms(verb), excl_prepos=[])):
    for relation in extract_rel_dep(coref_doc, pred_name=verb, pred_synonyms=[verb]+synonyms(verb), excl_prepos=[]):
        print(relation)
# Out:
# (('GAF', 'ORG'), offered, ('three billion dlrs', 'MONEY'))

# %%
mergers_article = """Microsoft Corp (MSFT.O) is buying "Call of Duty" maker Activision Blizzard (ATVI.O) for $68.7 billion in the biggest gaming industry deal in history as global technology giants stake their claims to a virtual future.

The all-cash deal announced by Microsoft on Tuesday, its biggest-ever acquisition, will bolster its firepower in the booming videogaming market where it takes on leaders Tencent (0700.HK) and Sony (6758.T).

It also represents the American multinational's bet on the "metaverse", virtual online worlds where people can work, play and socialize, as many of its biggest competitors are already doing. read more

"Gaming is the most dynamic and exciting category in entertainment across all platforms today and will play a key role in the development of metaverse platforms," Microsoft Chief Executive Satya Nadella said.

Microsoft's offer of $95 per share represents a premium of 45% to Activision's Friday close. Shares of Activision were at $83.35 in early trading.

The deal comes at a time of weakness for Activision, maker of games such as "Overwatch" and "Candy Crush". Its shares have slumped more than 37% since reaching a record high last year, hit by allegations of sexual harassment of employees and misconduct by several top managers.

The company is still addressing those allegations and said on Monday it had fired or pushed out more than three dozen employees and disciplined another 40 since July.

CEO Bobby Kotick, who said Microsoft reached out to him for a possible buyout, would continue to be the CEO of Activision following the deal.

In a conference call with analysts, Microsoft boss Nadella did not directly refer to the scandal but talked about the importance of culture in the company.

"It's critical for Activision Blizzard to drive forward on its renewed cultural commitments," he said, adding "the success of this acquisition will depend on it."

'METAVERSE ARMS RACE'

The global gaming market was valued at $173.70 billion in 2021, and is expected to reach $314.40 billion by 2027, according to research firm Mordor Intelligence.

Microsoft can already claim a significant beachhead in the gaming world as one of the big three console makers. It has been making big investments including up "Minecraft" maker Mojang Studios and Zenimax in multi-billion dollar deals in recent years.

It has also launched a popular cloud gaming service, which has more than 25 million subscribers.

Executives talked up Activision's 400 million monthly active users as one major attraction to the deal and how vital these communities could play in Microsoft's various metaverse plays.

Activision's library of games could give Microsoft's Xbox gaming platform an edge over Sony's Playstation, which has for years enjoyed a more steady stream of exclusive games.

"The likes of Netflix have already said they'd like to foray into gaming themselves, but Microsoft has come out swinging with today’s rather generous offer, which would make Microsoft the third largest gaming company in the world," said Sophie Lund-Yates, equity analyst at Hargreaves Lansdown.

Tech companies from Microsoft to Nvidia have placed big bets on the so-called metaverse, with the buzz around it intensifying late last year after Facebook renamed itself as Meta Platforms to reflect its focus on its virtual reality business.

"This is a significant deal for the consumer side of the business and more importantly, Microsoft acquiring Activision really starts the metaverse arms race," David Wagner, Equity Analyst and Portfolio Manager at Aptus Capital Advisors said.

"We believe the deal will get done," he said, but cautioned "This will get a lot of looks from a regulatory standpoint."

Lawmakers on Capitol Hill, who are considering a long list of antitrust bills aimed at reining in Big Tech companies like Google and Facebook, will be skeptical of this transaction, said Andre Barlow of the law firm Doyle, Barlow & Mazard PLLC.

"Microsoft is already big in gaming," he said."""
mergers_doc = nlp(clean(mergers_article))

# %%
if peek(extract_rel_dep(mergers_doc, pred_name=verb, pred_synonyms=[verb]+synonyms(verb), excl_prepos=[])):
    for relation in extract_rel_dep(mergers_doc, pred_name=verb, pred_synonyms=[verb]+synonyms(verb), excl_prepos=[]):
        print(relation)

# %%
displacy.render(mergers_doc,style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft Corp
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MSFT.O
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) is buying &quot;
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Call of Duty
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# &quot; maker
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Activision Blizzard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ATVI.O
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $68.7 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in the biggest gaming industry deal in history as global technology giants stake their claims to a virtual future.The all-cash deal announced by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , its biggest-ever acquisition, will bolster its firepower in the booming videogaming market where it takes on leaders
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tencent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (0700.HK) and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sony
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6758.T).It
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  also represents the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  multinational's bet on the &quot;metaverse&quot;, virtual online worlds where people can work, play and socialize, as many of its biggest competitors are already doing. read more&quot;Gaming is the most dynamic and exciting category in entertainment across all platforms
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and will play a key role in the development of metaverse platforms,&quot;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Chief Executive
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Satya Nadella
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's offer of $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     95
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  per share represents a premium of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     45%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Activision
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  close. Shares of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Activision
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  were at $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     83.35
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in early trading.The deal comes at a time of weakness for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Activision
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , maker of games such as &quot;Overwatch&quot; and &quot;
# <

# %%
merger_sent = """Microsoft Corp (MSFT.O) is buying "Call of Duty" maker Activision Blizzard (ATVI.O) for $68.7 billion in the biggest gaming industry deal in history as global technology giants stake their claims to a virtual future."""
merger_sent_doc = nlp(clean(merger_sent))

# %%
if peek(extract_rel_dep(merger_sent_doc, pred_name=verb, pred_synonyms=[verb]+synonyms(verb), excl_prepos=[])):
    for relation in extract_rel_dep(merger_sent_doc, pred_name=verb, pred_synonyms=[verb]+synonyms(verb), excl_prepos=[]):
        print(relation)

# %%
displacy.render(merger_sent_doc,style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="07c42ef3815c47c8abd7aebf0f5a77b9-0" class="displacy" width="6175" height="837.0" direction="ltr" style="max-width: none; height: 837.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Microsoft</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Corp (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">MSFT.O)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">buying &quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">Call</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Duty&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">maker</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Activision</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Blizzard (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">ATVI.O)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">68.7</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">billion</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">biggest</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">gaming</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">industry</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">deal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">history</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">global</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">technology</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">giants</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">stake</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">their</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">claims</tspan>
#     <tspan class="displa

# %%
reuters.raw(reuters_fileids_crude[1])
# Out:
# 'ENERGY/U.S. PETROCHEMICAL INDUSTRY\n  Cheap oil feedstocks, the weakened U.S.\n  dollar and a plant utilization rate approaching 90 pct will\n  propel the streamlined U.S. petrochemical industry to record\n  profits this year, with growth expected through at least 1990,\n  major company executives predicted.\n      This bullish outlook for chemical manufacturing and an\n  industrywide move to shed unrelated businesses has prompted GAF\n  Corp &lt;GAF>, privately-held Cain Chemical Inc, and other firms\n  to aggressively seek acquisitions of petrochemical plants.\n      Oil companies such as Ashland Oil Inc &lt;ASH>, the\n  Kentucky-based oil refiner and marketer, are also shopping for\n  money-making petrochemical businesses to buy.\n      "I see us poised at the threshold of a golden period," said\n  Paul Oreffice, chairman of giant Dow Chemical Co &lt;DOW>, adding,\n  "There\'s no major plant capacity being added around the world\n  now. The whole game is bringing out new products and improving\n  the old ones."\n      Analysts say the chemical industry\'s biggest customers,\n  automobile manufacturers and home builders that use a lot of\n  paints and plastics, are expected to buy quantities this year.\n      U.S. petrochemical plants are currently operating at about\n  90 pct capacity, reflecting tighter supply that could hike\n  product prices by 30 to 40 pct this year, said John Dosher,\n  managing director of Pace Consultants Inc of Houston. Demand\n  for some products such as styrene could push profit margins up\n  by as much as 300 pct, he said.\n      Oreffice, speaking at a meeting of chemical engineers in\n  Houston, said Dow would easily top the 741 mln dlrs it earned\n  last year and predicted it would have the best year in its\n  history.\n      In 1985, when oil prices were still above 25 dlrs a barrel\n  and chemical exports were adversely affected by the strong U.S.\n  dollar, Dow had profits of 58 mln dlrs. "I believe the entire\n  chemical industry is headed for a record year or close to it,"\n  Oreffice said.\n      GAF chairman Samuel Heyman estimated that the U.S. chemical\n  industry would report a 20 pct gain in profits during 1987.\n  Last year, the domestic industry earned a total of 13 billion\n  dlrs, a 54 pct leap from 1985.\n      The turn in the fortunes of the once-sickly chemical\n  industry has been brought about by a combination of luck and\n  planning, said Pace\'s John Dosher.\n      Dosher said last year\'s fall in oil prices made feedstocks\n  dramatically cheaper and at the same time the American dollar\n  was weakening against foreign currencies. That helped boost\n  U.S. chemical exports.\n      Also helping to bring supply and demand into balance has\n  been the gradual market absorption of the extra chemical\n  manufacturing capacity created by Middle Eastern oil producers\n  in the early 1980s.\n      Finally, virtually all major U.S. chemical manufacturers\n  have embarked on an extensive corporate restructuring program\n  to mothball inefficient plants, trim the payroll and eliminate\n  unrelated businesses. The restructuring touched off a flurry of\n  friendly and hostile takeover attempts.\n      GAF, which made an unsuccessful attempt in 1985 to acquire\n  Union Carbide Corp &lt;UK>, recently offered three billion dlrs\n  for Borg Warner Corp &lt;BOR>, a Chicago manufacturer of plastics\n  and chemicals. Another industry powerhouse, W.R. Grace &lt;GRA> \n  has divested its retailing, restaurant and fertilizer\n  businesses to raise cash for chemical acquisitions.\n      But some experts worry that the chemical industry may be\n  headed for trouble if companies continue turning their back on\n  the manufacturing of staple petrochemical commodities, such as\n  ethylene, in favor of more profitable specialty chemicals that\n  are custom-designed for a small group of buyers.\n      "Companies like DuPont &lt;DD> and Monsanto Co &lt;MTC> spent the\n  past two or three years trying  ...

# %%
reuters.raw(reuters_fileids_crude[2])
# Out:
# 'TURKEY CALLS FOR DIALOGUE TO SOLVE DISPUTE\n  Turkey said today its disputes with\n  Greece, including rights on the continental shelf in the Aegean\n  Sea, should be solved through negotiations.\n      A Foreign Ministry statement said the latest crisis between\n  the two NATO members stemmed from the continental shelf dispute\n  and an agreement on this issue would effect the security,\n  economy and other rights of both countries.\n      "As the issue is basicly political, a solution can only be\n  found by bilateral negotiations," the statement said. Greece has\n  repeatedly said the issue was legal and could be solved at the\n  International Court of Justice.\n      The two countries approached armed confrontation last month\n  after Greece announced it planned oil exploration work in the\n  Aegean and Turkey said it would also search for oil.\n      A face-off was averted when Turkey confined its research to\n  territorrial waters. "The latest crises created an historic\n  opportunity to solve the disputes between the two countries,"\n  the Foreign Ministry statement said.\n      Turkey\'s ambassador in Athens, Nazmi Akiman, was due to\n  meet Prime Minister Andreas Papandreou today for the Greek\n  reply to a message sent last week by Turkish Prime Minister\n  Turgut Ozal. The contents of the message were not disclosed.\n  \n\n'

# %%
trial = nlp("GAF, which made an unsuccessful attempt in 1985 to acquire Union Carbide Corp &lt;UK>, recently offered three billion dlrs for Borg Warner Corp &lt;BOR>, a Chicago manufacturer of plastics and chemicals.")

# %%
displacy.render(trial, style="dep",options={'compact': False, 'distance': 100})
# Out:
# '<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d3045579267b4474bcbba5d7f853d880-0" class="displacy" width="3350" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">\n<text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">\n    <tspan class="displacy-word" fill="currentColor" x="50">GAF,</tspan>\n    <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>\n</text>\n\n<text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">\n    <tspan class="displacy-word" fill="currentColor" x="150">which</tspan>\n    <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">DET</tspan>\n</text>\n\n<text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">\n    <tspan class="displacy-word" fill="currentColor" x="250">made</tspan>\n    <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">VERB</tspan>\n</text>\n\n<text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">\n    <tspan class="displacy-word" fill="currentColor" x="350">an</tspan>\n    <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">DET</tspan>\n</text>\n\n<text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">\n    <tspan class="displacy-word" fill="currentColor" x="450">unsuccessful</tspan>\n    <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADJ</tspan>\n</text>\n\n<text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">\n    <tspan class="displacy-word" fill="currentColor" x="550">attempt</tspan>\n    <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">NOUN</tspan>\n</text>\n\n<text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">\n    <tspan class="displacy-word" fill="currentColor" x="650">in</tspan>\n    <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>\n</text>\n\n<text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">\n    <tspan class="displacy-word" fill="currentColor" x="750">1985</tspan>\n    <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NUM</tspan>\n</text>\n\n<text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">\n    <tspan class="displacy-word" fill="currentColor" x="850">to</tspan>\n    <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">PART</tspan>\n</text>\n\n<text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">\n    <tspan class="displacy-word" fill="currentColor" x="950">acquire</tspan>\n    <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">VERB</tspan>\n</text>\n\n<text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">\n    <tspan class="displacy-word" fill="currentColor" x="1050">Union</tspan>\n    <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">PROPN</tspan>\n</text>\n\n<text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">\n    <tspan class="displacy-word" fill="currentColor" x="1150">Carbide</tspan>\n    <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">PROPN</tspan>\n</text>\n\n<text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">\n    <tspan class="displacy-word" fill="currentColor" x="1250">Corp &amp;</tspan>\n    <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>\n</text>\n\n<text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">\n    <tspan class="displacy-word" fill="currentColor" x="1350">lt;UK</tspan>\n    <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">NOUN</tspan>\n</text>\n\n<text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">\n    <tspan class="displacy-word" fill="currentColor" x="1450">&g ...

# %%
for t in trial:
    print("TOKEN: ",t,"\ndepencies:",t.dep_,"\npos: ",t.pos_,"\ntoken's head:", t.head)
    if peek(t.children):
        print("Children:")
        for child in t.children:
            print(child)
    if peek(t.lefts):
        print("Lefts:")
        for left in t.lefts:
            print(left)
    if peek(t.rights):
        print("Rights:")
        for right in t.rights:
            print(right)
    print("\n")
# Out:
# TOKEN:  GAF
# depencies: nsubj
# pos:  PROPN
# token's head: offered
# Children:
# ,
# made
# >
# ,
# Rights:
# ,
# made
# >
# ,
#
#
# TOKEN:  ,
# depencies: punct
# pos:  PUNCT
# token's head: GAF
#
#
# TOKEN:  which
# depencies: nsubj
# pos:  DET
# token's head: made
#
#
# TOKEN:  made
# depencies: relcl
# pos:  VERB
# token's head: GAF
# Children:
# which
# attempt
# Lefts:
# which
# Rights:
# attempt
#
#
# TOKEN:  an
# depencies: det
# pos:  DET
# token's head: attempt
#
#
# TOKEN:  unsuccessful
# depencies: amod
# pos:  ADJ
# token's head: attempt
#
#
# TOKEN:  attempt
# depencies: dobj
# pos:  NOUN
# token's head: made
# Children:
# an
# unsuccessful
# in
# acquire
# Lefts:
# an
# unsuccessful
# Rights:
# in
# acquire
#
#
# TOKEN:  in
# depencies: prep
# pos:  ADP
# token's head: attempt
# Children:
# 1985
# Rights:
# 1985
#
#
# TOKEN:  1985
# depencies: pobj
# pos:  NUM
# token's head: in
#
#
# TOKEN:  to
# depencies: aux
# pos:  PART
# token's head: acquire
#
#
# TOKEN:  acquire
# depencies: acl
# pos:  VERB
# token's head: attempt
# Children:
# to
# Corp
# Lefts:
# to
# Rights:
# Corp
#
#
# TOKEN:  Union
# depencies: compound
# pos:  PROPN
# token's head: Corp
#
#
# TOKEN:  Carbide
# depencies: compound
# pos:  PROPN
# token's head: Corp
#
#
# TOKEN:  Corp
# depencies: dobj
# pos:  PROPN
# token's head: acquire
# Children:
# Union
# Carbide
# &
# lt;UK
# Lefts:
# Union
# Carbide
# Rights:
# &
# lt;UK
#
#
# TOKEN:  &
# depencies: cc
# pos:  CCONJ
# token's head: Corp
#
#
# TOKEN:  lt;UK
# depencies: conj
# pos:  NOUN
# token's head: Corp
#
#
# TOKEN:  >
# depencies: appos
# pos:  X
# token's head: GAF
#
#
# TOKEN:  ,
# depencies: punct
# pos:  PUNCT
# token's head: GAF
#
#
# TOKEN:  recently
# depencies: advmod
# pos:  ADV
# token's head: offered
#
#
# TOKEN:  offered
# depencies: ROOT
# pos:  VERB
# token's head: offered
# Children:
# GAF
# recently
# dlrs
# for
# >
# ,
# .
# Lefts:
# GAF
# recently
# Rights:
# dlrs
# for
# >
# ,
# .
#
#
# TOKEN:  three
# depencies: compound
# pos:  NUM
# token's head: billion
#
#
# TOKEN:  billion
# depencies: nummod
# pos:  NUM
# token's head: dlrs
# Children:
# three
# Lefts:
# three
#
#
# TOKEN:  dlrs
# depencies: dobj
# pos:  NOUN
# token's head: offered
# Children:
# billion
# manufacturer
# Lefts:
# billion
# Rights:
# manufacturer
#
#
# TOKEN:  for
# depencies: prep
# pos:  ADP
# token's head: offered
# Children:
# Corp
# Rights:
# Corp
#
#
# TOKEN:  Borg
# depencies: compound
# pos:  PROPN
# token's head: Corp
#
#
# TOKEN:  Warner
# depencies: compound
# pos:  PROPN
# token's head: Corp
#
#
# TOKEN:  Corp
# depencies: pobj
# pos:  PROPN
# token's head: for
# Children:
# Borg
# Warner
# &
# lt;BOR
# Lefts:
# Borg
# Warner
# Rights:
# &
# lt;BOR
#
#
# TOKEN:  &
# depencies: cc
# pos:  CCONJ
# token's head: Corp
#
#
# TOKEN:  lt;BOR
# depencies: conj
# pos:  PROPN
# token's head: Corp
#
#
# TOKEN:  >
# depencies: dobj
# pos:  X
# token's head: offered
#
#
# TOKEN:  ,
# depencies: punct
# pos:  PUNCT
# token's head: offered
#
#
# TOKEN:  a
# depencies: det
# pos:  DET
# token's head: manufacturer
#
#
# TOKEN:  Chicago
# depencies: compound
# pos:  PROPN
# token's head: manufacturer
#
#
# TOKEN:  manufacturer
# depencies: appos
# pos:  NOUN
# token's head: dlrs
# Children:
# a
# Chicago
# of
# Lefts:
# a
# Chicago
# Rights:
# of
#
#
# TOKEN:  of
# depencies: prep
# pos:  ADP
# token's head: manufacturer
# Children:
# plastics
# Rights:
# plastics
#
#
# TOKEN:  plastics
# depencies: pobj
# pos:  NOUN
# token's head: of
# Children:
# and
# chemicals
# Rights:
# and
# chemicals
#
#
# TOKEN:  and
# depencies: cc
# pos:  CCONJ
# token's head: plastics
#
#
# TOKEN:  chemicals
# depencies: conj
# pos:  NOUN
# token's head: plastics
#
#
# TOKEN:  .
# depencies: punct
# pos:  PUNCT
# token's head: offered

# %%
trial
# Out:
# GAF, which made an unsuccessful attempt in 1985 to acquire Union Carbide Corp &lt;UK>, recently offered three billion dlrs for Borg Warner Corp &lt;BOR>, a Chicago manufacturer of plastics and chemicals.

# %%
verb = "offer"
if peek(extract_rel_dep(trial, pred_name=verb, pred_synonyms=[verb]+synonyms(verb), excl_prepos=[])):
    for relation in extract_rel_dep(trial, pred_name=verb, pred_synonyms=[verb]+synonyms(verb), excl_prepos=[]):
        print(relation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5565/1676760680.py in <module>
#       1 verb = "offer"
# ----> 2 if peek(extract_rel_dep(trial, pred_name=verb, pred_synonyms=[verb]+synonyms(verb), excl_prepos=[])):
#       3     for relation in extract_rel_dep(trial, pred_name=verb, pred_synonyms=[verb]+synonyms(verb), excl_prepos=[]):
#       4         print(relation)
#
# NameError: name 'trial' is not defined

# %%
reuters.words(reuters_fileids_crude[1])
# Out:
# ['ENERGY', '/', 'U', '.', 'S', '.', 'PETROCHEMICAL', ...]

# %%
crude = ""
for fileid in reuters.fileids("crude"):#[0:50]:
    file = reuters.raw(fileid)
    file = clean(file)
    crude = crude + " " + file
crude = crude.strip()

# %%
crude_doc = nlp(crude)

# %%
entities = []
for ent in crude_doc.ents:
    if ent.label_ == "MONEY":
        entities.append(ent.text)

# %%
verb = "sell"
subjects = []
subjects_label = []
verbs = []
objects = []
objects_label = []
if peek(extract_rel_dep(crude_doc, pred_name=verb, pred_synonyms=[verb]+synonyms(verb), excl_prepos=[])):
    for relation in extract_rel_dep(crude_doc, pred_name=verb, pred_synonyms=[verb]+synonyms(verb), excl_prepos=[]):
        print(relation)
        subject_tuple, verb, object_tuple = relation
        subjects.append(subject_tuple[0])
        subjects_label.append(subject_tuple[1])
        verbs.append(verb)
        objects.append(object_tuple[0])
        objects_label.append(object_tuple[1])
# Out:
# (('GAF', 'ORG'), made, ('Union Carbide Corp', 'ORG'))
# (('GAF', 'ORG'), acquire, ('Union Carbide Corp', 'ORG'))
# (('GAF', 'ORG'), offered, ('Borg Warner Corp', 'ORG'))
# (('Texaco', 'ORG'), told, ('Texaco', 'ORG'))
# (('Texaco', 'ORG'), filed, ('Pennzoil', 'ORG'))
# (('Texaco', 'ORG'), failing, ('Pennzoil', 'ORG'))
# (('Texaco', 'ORG'), reach, ('Pennzoil', 'ORG'))
# (('Texaco', 'ORG'), filed, ('Pennzoil', 'ORG'))
# (('Texaco', 'ORG'), failing, ('Pennzoil', 'ORG'))
# (('Texaco', 'ORG'), reach, ('Pennzoil', 'ORG'))
# (('Aramco', 'ORG'), purchase, ('Exxon Corp', 'ORG'))
# (('Aramco', 'ORG'), allocated, ('Exxon Corp', 'ORG'))
# (('Council', 'ORG'), tell, ('MITI', 'ORG'))
# (('SANTOS', 'ORG'), ACQUIRE, ('Santos Ltd &lt;STOS.S', 'ORG'))
# (('SANTOS', 'ORG'), said, ('Pty Ltd', 'ORG'))
# (('SANTOS', 'ORG'), buy, ('Pty Ltd', 'ORG'))
# (('SANTOS', 'ORG'), lt;Total, ('Pty Ltd', 'ORG'))
# (('Hodel', 'ORG'), urged, ('Congress', 'ORG'))
# (('Lukman', 'ORG'), said, ('OPEC', 'ORG'))
# (('Lukman', 'ORG'), depended, ('OPEC', 'ORG'))
# (('Hodel', 'ORG'), urged, ('Congress', 'ORG'))
# (('API', 'ORG'), SAYS, ('Amoco Canada Petroleum Co Ltd', 'ORG'))
# (('API', 'ORG'), SAYS, ('Amoco Canada Petroleum Co Ltd', 'ORG'))
# (('API', 'ORG'), SAYS, ('Amoco Canada Petroleum Co Ltd', 'ORG'))
# (('API', 'ORG'), said, ('Dome Petroleum Ltd', 'ORG'))
# (('Stacy', 'ORG'), described, ("Amoco Canada's", 'ORG'))
# (('Amoco', 'ORG'), planned, ('Dome', 'ORG'))
# (('Amoco', 'ORG'), reinvest, ('Amoco Canada-Dome', 'ORG'))
# (('Westcoast', 'ORG'), said, ('AGIP Canada Ltd', 'ORG'))
# (('Westcoast', 'ORG'), enable, ('AGIP Canada Ltd', 'ORG'))
# (('Westcoast', 'ORG'), apply, ('AGIP Canada Ltd', 'ORG'))
# (('OPEC', 'ORG'), said, ('Merrill Lynch Futures', 'ORG'))
# (('KUWAIT', 'ORG'), SEES, ('OPEC', 'ORG'))
# (('KUWAIT', 'ORG'), agreed, ('OPEC', 'ORG'))
# (('INA', 'ORG'), REJECTS, ('OPEC', 'ORG'))
# (('INA', 'ORG'), rejected, ('OPEC', 'ORG'))
# (('Chevron', 'ORG'), said, ('U.K. Continental', 'ORG'))
# (('Chevron', 'ORG'), operates, ('British Petroleum Development Ltd', 'ORG'))
# (('Chevron', 'ORG'), include, ('British Petroleum Development Ltd', 'ORG'))
# (('BCV', 'ORG'), According, ('PDVSA', 'ORG'))
# (('Kellogg', 'ORG'), pointed, ('BTX', 'ORG'))
# (('Kellogg', 'ORG'), imports, ('BTX', 'ORG'))
# (('Ekofisk', 'ORG'), shut, ('Ekofisk', 'ORG'))
# (('Phillips', 'ORG'), raised, ('Ekofisk', 'ORG'))
# (('Crowe', 'ORG'), told, ('American Stock Exchange', 'ORG'))
# (('IRAN', 'ORG'), said, ('U.S. Attack', 'ORG'))
# (('IRNA', 'ORG'), said, ('Resalat', 'ORG'))
# (('IRNA', 'ORG'), identified, ('Resalat', 'ORG'))
# (('Statoil', 'ORG'), said, ('Aker Norcem A/S &lt;AMVO.OL', 'ORG'))
# (('Chase', 'ORG'), said, ("Standard Oil's", 'ORG'))
# (('USX', 'ORG'), SAYS, ('British Petroleum Co Plc', 'ORG'))
# (('USX', 'ORG'), said, ('British Petroleum Co Plc', 'ORG'))
# (('USX', 'ORG'), ended, ('British Petroleum Co Plc', 'ORG'))
# (('USX', 'ORG'), said, ('BP', 'ORG'))
# (('USX', 'ORG'), held, ('BP', 'ORG'))
# (('USX', 'ORG'), had, ('Marathon Oil Co', 'ORG'))
# (('USX', 'ORG'), restructure, ('Marathon Oil Co', 'ORG'))
# (('Ergenc', 'ORG'), told, ('Reuters', 'ORG'))
# (('NATO', 'ORG'), CALLS, ('NATO', 'ORG'))
# (('NATO', 'ORG'), AVOID, ('NATO', 'ORG'))
# (('OPEC', 'ORG'), renew, ('OPEC', 'ORG'))
# (('CSR', 'ORG'), said, ('Exxon Corp unit &lt;Esso Exploration and Production Australia Inc>', 'ORG'))
# (('CSR', 'ORG'), dropped, ('Exxon Corp unit &lt;Esso Exploration and Production Australia Inc>', 'ORG'))
# (('CSR', 'ORG'), sell, ('Exxon Corp unit &lt;Esso Exploration and Production Australia Inc>', 'ORG'))
# (('CSR', 'ORG'), gets, ('Esso', 'ORG'))
# (('CSR', 'ORG'), has, ('Esso', 'ORG'))
# (('CSR', 'ORG'), share, ('Esso', 'ORG'))
# (('CSR', 'ORG'), said, ('Exxon Corp', 'ORG'))
# (('CSR', 'ORG'), dropped, ('Exxon Corp', 'ORG'))
# (('CSR', 'ORG'), sell, ('Exxon Corp', 'ORG'))
# (('EXXON', 'ORG'), GAINS, ('OPERATIONS Exxon Corp', 'ORG'))
# (('CHEVRON', 'ORG'), said, ('Chevron', 'ORG'))
# (('CHEVRON', 'ORG'), agreed, ('Chevron', 'ORG'))
# (('CHEVRON', 'ORG'), conduct, ('Chevron', 'ORG'))
# (('IMPERIAL OIL &lt;IMO.A> IN TALKS WITH', 'ORG'), owned, ('Exxon Corp', 'ORG'))
# (('MOBIL', 'ORG'), RAISES, ('DLR', 'ORG'))
# (('Mobil', 'ORG'), said, ('API', 'ORG'))
# (('Mobil', 'ORG'), changed, ('API', 'ORG'))
# (('Petrobras', 'ORG'), cancelled, ('Bank of Brazil', 'ORG'))
# (('Petrobras', 'ORG'), refused, ('Bank of Brazil', 'ORG'))
# (('Petrobras', 'ORG'), accept, ('Bank of Brazil', 'ORG'))
# (('Texaco Canada Inc', 'ORG'), owned, ('Texaco Inc', 'ORG'))
# (('PANCANADIAN', 'ORG'), SELL, ('IEA', 'ORG'))
# (('PANCANADIAN', 'ORG'), SELL, ('IEA', 'ORG'))
# (('IEA', 'ORG'), estimates, ('OECD', 'ORG'))
# (('IEA', 'ORG'), put, ('OECD', 'ORG'))
# (('IEA', 'ORG'), FORECASTS, ('OECD', 'ORG'))
# (('IEA', 'ORG'), estimates, ('OECD', 'ORG'))
# (('IEA', 'ORG'), put, ('OECD', 'ORG'))
# (('IEA', 'ORG'), held, ('OECD', 'ORG'))
# (('IEA', 'ORG'), said, ('OECD', 'ORG'))
# (('IEA', 'ORG'), indicate, ('OECD', 'ORG'))
# (('IEA', 'ORG'), fell, ('OECD', 'ORG'))
# (('API', 'ORG'), SAYS, ('Petroleum Ltd>', 'ORG'))
# (('API', 'ORG'), SAYS, ('Petroleum Ltd>', 'ORG'))
# (('API', 'ORG'), SELL, ('Petroleum Ltd>', 'ORG'))
# (('API', 'ORG'), said, ('Whitehall Petroleum Ltd', 'ORG'))
# (('API', 'ORG'), agreed, ('Whitehall Petroleum Ltd', 'ORG'))
# (('API', 'ORG'), sell, ('Whitehall Petroleum Ltd', 'ORG'))
# (('PanCanadian', 'ORG'), owned, ('Canadian Pacific Ltd', 'ORG'))
# (('Wellemeyer', 'ORG'), said, ('OPEC', 'ORG'))
# (('Wellemeyer', 'ORG'), push, ('OPEC', 'ORG'))
# (('OPEC', 'ORG'), said, ('Petroleum Analysis Ltd', 'ORG'))
# (('IBJ', 'ORG'), plan, ('Japan Line', 'ORG'))
# (('IBJ', 'ORG'), abandon, ('Japan Line', 'ORG'))
# (('OPEC', 'ORG'), SAYS, ('OPEC', 'ORG'))
# (('OPEC', 'ORG'), quoted, ('OPEC', 'ORG'))
# (('OPEC', 'ORG'), hold, ('OPEC', 'ORG'))
# (('OPEC', 'ORG'), discuss, ('OPEC', 'ORG'))
# (('OPEC', 'ORG'), prices, ('OPEC', 'ORG'))
# (('KUWAIT', 'ORG'), SAYS, ('OPEC', 'ORG'))
# (('KUWAIT', 'ORG'), said, ('OPEC', 'ORG'))
# (('KUWAIT', 'ORG'), were, ('OPEC', 'ORG'))
# (('Lukman', 'ORG'), said, ('Opec', 'ORG'))
# (('Lukman', 'ORG'), produced, ('Opec', 'ORG'))
# (('Lukman', 'ORG'), said, ('Opec', 'ORG'))
# (('Lukman', 'ORG'), refusing, ('Opec', 'ORG'))
# (('Lukman', 'ORG'), lift, ('Opec', 'ORG'))
# (('Lukman', 'ORG'), have, ('Opec', 'ORG'))
# (('Lukman', 'ORG'), buy, ('Opec', 'ORG'))
# (('OPEC', 'ORG'), said, ('Smith Barney, Harris Upham and Co.', 'ORG'))
# (('EIU', 'ORG'), said, ('World Trade Forecast', 'ORG'))
# (('EIU', 'ORG'), said, ('OPEC', 'ORG'))
# (('RANGER', 'ORG'), COMPLETES, ('Ampol Exploration Ltd', 'ORG'))
# (('RANGER', 'ORG'), said, ('Ampol Exploration Ltd', 'ORG'))
# (('RANGER', 'ORG'), completed, ('Ampol Exploration Ltd', 'ORG'))
# (('RANGER', 'ORG'), held, ('Ranger Oil Co', 'ORG'))
# (('DiBona', 'ORG'), fallen, ('OPEC', 'ORG'))
# (('DiBona', 'ORG'), raised, ('OPEC', 'ORG'))
# (('Conoco', 'ORG'), raise, ('Sun Co', 'ORG'))
# (('Conoco', 'ORG'), following, ('Sun Co', 'ORG'))
# (('Conoco', 'ORG'), initiated, ('Sun Co', 'ORG'))
# (('WAM', 'ORG'), said, ('Gulf Cooperation Council', 'ORG'))
# (('WAM', 'ORG'), discussing, ('Gulf Cooperation Council', 'ORG'))
# (('Lukman', 'ORG'), put, ('OPEC', 'ORG'))
# (('USX', 'ORG'), RAISE, ('Marathon Petroleum Co', 'ORG'))
# (('USX', 'ORG'), owns, ('Marathon Oil Co', 'ORG'))
# (('PHILLIPS', 'ORG'), emphasize, ('Reuters', 'ORG'))
# (('C.J. "Pete" Silas', 'ORG'), told, ('Reuters', 'ORG'))
# (('MOBIL', 'ORG'), RESTRUCTURE, ('Mobil Oil Corp', 'ORG'))
# (('MOBIL', 'ORG'), said, ('Mobil Exploration and Producing Services Inc', 'ORG'))
# (('MOBIL', 'ORG'), restructure, ('Mobil Exploration and Producing Services Inc', 'ORG'))
# (('Mobil', 'ORG'), said, ('Technical Services and Application Technology', 'ORG'))
# (('Mobil', 'ORG'), consist, ('Technical Services and Application Technology', 'ORG'))
# (('PHILLIPS', 'ORG'), RAISES, ('CTS', 'ORG'))
# (('PHILLIPS', 'ORG'), RAISES, ('CTS', 'ORG'))
# (('UNOCAL', 'ORG'), RAISES, ('CTS', 'ORG'))
# (('UNOCAL', 'ORG'), RAISES, ('CTS', 'ORG'))
# (('CITGO RAISES CRUDE', 'ORG'), RAISES, ('CTS', 'ORG'))
# (('CITGO RAISES CRUDE', 'ORG'), RAISES, ('CTS', 'ORG'))
# (('Opec', 'ORG'), defend, ('Opec', 'ORG'))
# (('OPEC', 'ORG'), said, ('OPEC', 'ORG'))
# (('OPEC', 'ORG'), said, ('OPEC', 'ORG'))
# (('ORS', 'ORG'), said, ('IIT Research Institute', 'ORG'))
# (('PETROBRAS', 'ORG'), ASKS, ('ARMY', 'ORG'))
# (('PETROBRAS', 'ORG'), WITHDRAW, ('Army', 'ORG'))
# (('Petrobras', 'ORG'), asked, ('Army', 'ORG'))
# (('PDVSA', 'ORG'), pay, ('Champlin', 'ORG'))
# (('PDVSA', 'ORG'), pay, ('Champlin', 'ORG'))
# (('Petrobras', 'ORG'), said, ('Banco', 'ORG'))
# (('Petrobras', 'ORG'), accept, ('Banco', 'ORG'))
# (('Petrobras', 'ORG'), do, ('Brasil', 'ORG'))
# (('Petrobras', 'ORG'), cancelled, ('Bank of Brazil', 'ORG'))
# (('Petrobras', 'ORG'), refused, ('Bank of Brazil', 'ORG'))
# (('Petrobras', 'ORG'), accept, ('Bank of Brazil', 'ORG'))
# (('Ina', 'ORG'), signed, ('Hoechst AG &lt;HFAG.F> two years ago', 'ORG'))
# (('Ina', 'ORG'), has, ('Novi Sad', 'ORG'))
# (('Ina', 'ORG'), involving, ('Novi Sad', 'ORG'))
# (('Ina', 'ORG'), issued, ('Tanjug', 'ORG'))
# (('MEES', 'ORG'), said, ('OPEC', 'ORG'))
# (('MEES', 'ORG'), sent, ('OPEC', 'ORG'))
# (('Petrobras', 'ORG'), said, ('Banco', 'ORG'))
# (('Petrobras', 'ORG'), accept, ('Banco', 'ORG'))
# (('Petrobras', 'ORG'), do, ('Brasil', 'ORG'))
# (('Petrobras', 'ORG'), cancelled, ('Bank of Brazil', 'ORG'))
# (('Petrobras', 'ORG'), refused, ('Bank of Brazil', 'ORG'))
# (('Petrobras', 'ORG'), accept, ('Bank of Brazil', 'ORG'))
# (('Margoshes', 'ORG'), said, ('Atlantic Richfield', 'ORG'))
# (('Margoshes', 'ORG'), recommended, ('Atlantic Richfield', 'ORG'))
# (('EXXON', 'ORG'), CLOSE, ('Exxon Corp', 'ORG'))
# (('OPEC', 'ORG'), WANTS, ('OAPEC', 'ORG'))
# (('OPEC', 'ORG'), WANTS, ('OAPEC', 'ORG'))
# (('TEXACO', 'ORG'), CEASE, ('Texaco Refining and Marketing', 'ORG'))
# (('TEXACO', 'ORG'), POSTING, ('Texaco Refining and Marketing', 'ORG'))
# (('Herrington', 'ORG'), said, ('Administration', 'ORG'))
# (('TMOC', 'ORG'), has, ('Moonie', 'ORG'))
# (('TMOC', 'ORG'), including, ('Moonie', 'ORG'))
# (('TMOC', 'ORG'), owns, ('Moonie', 'ORG'))
# (('TMOC', 'ORG'), owns, ('Moonie', 'ORG'))
# (('TMOC', 'ORG'), operates, ('Moonie', 'ORG'))
# (('TMOC', 'ORG'), holds, ('Moonie', 'ORG'))
# (('Patrick', 'ORG'), pay, ('Bayou', 'ORG'))
# (('Iranian Foreign Ministry', 'ORG'), quoted, ('BBC', 'ORG'))
# (('Iranian Foreign Ministry', 'ORG'), monitored, ('BBC', 'ORG'))
# (('Haslam', 'ORG'), said, ('PRT', 'ORG'))
# (('GOODYEAR', 'ORG'), START, ('Rubber Co', 'ORG'))
# (('IMPERIAL OIL &lt;IMO.A', 'ORG'), owned, ('Exxon Corp', 'ORG'))
# (('API', 'ORG'), SAYS, ('ANNOUCE', 'ORG'))
# (('API', 'ORG'), SAYS, ('ANNOUCE', 'ORG'))
# (('PEMEX', 'ORG'), SIGNS, ('Petroleos Mexicanos', 'ORG'))
# (('PEMEX', 'ORG'), signed, ('Pacific Petroleum Project', 'ORG'))
# (('PEMEX', 'ORG'), finance, ('Pacific Petroleum Project', 'ORG'))
# (('Pemex', 'ORG'), have, ('LPG', 'ORG'))
# (('Statoil', 'ORG'), share, ('Tenneco Inc &lt;TGT.N>', 'ORG'))
# (('Texas Eastern and &lt;Petroleo', 'ORG'), offered, ('Deminex', 'ORG'))
# (('Statoil', 'ORG'), head, ("Exxon Corp's", 'ORG'))
# (('Statoil', 'ORG'), sharing, ("Exxon Corp's", 'ORG'))
# (('Herrington', 'ORG'), pressed, ('Administration', 'ORG'))
# (('PENNZOIL', 'ORG'), said, ('Texaco Inc', 'ORG'))
# (('PENNZOIL', 'ORG'), received, ('Texaco Inc', 'ORG'))
# (('PENNZOIL', 'ORG'), added, ('Texaco', 'ORG'))
# (('PENNZOIL', 'ORG'), remained, ('Texaco', 'ORG'))
# (('PENNZOIL', 'ORG'), consider, ('Texaco', 'ORG'))
# (('PENNZOIL', 'ORG'), settle, ('Texaco', 'ORG'))
# (('PENNZOIL', 'ORG'), won, ('Texaco', 'ORG'))
# (('Pennzoil', 'ORG'), has, ('Texaco', 'ORG'))
# (('Pennzoil', 'ORG'), receive, ('Texaco', 'ORG'))
# (('Pennzoil', 'ORG'), dropped, ('mcf', 'ORG'))
# (('ministry of energy', 'ORG'), MEET, ('CARACAS Five', 'ORG'))
# (("British Petroleum Co PLC's", 'ORG'), intends, ('Standard Oil Co', 'ORG'))
# (("British Petroleum Co PLC's", 'ORG'), tender, ('Standard Oil Co', 'ORG'))
# (("British Petroleum Co PLC's", 'ORG'), intends, ('Standard Oil Co', 'ORG'))
# (("British Petroleum Co PLC's", 'ORG'), tender, ('Standard Oil Co', 'ORG'))

# %%
relationships = pd.DataFrame({"subject":subjects,"subject_label":subjects_label,"verb":verbs,"object":objects,"object_label":objects_label})

# %%
relationships.to_csv("data/relationships-ORG_ORG.csv")

# %%
edges = pd.DataFrame({"from":subjects,"to":objects,"label":verbs})
edges.to_csv("data/edges.csv")
nodes = pd.DataFrame({"id":subjects+objects,"Type":subjects_label+objects_label})
nodes.to_csv("data/nodes.csv")

# %%
for sentence in crude_doc.sents:
    for ent in sentence.ents:
        if ent.label_ == "MONEY" and ent.text in entities:
            displacy.render(sentence, style="ent")

# %%
crude_doc.sents

# %%
predictor = Predictor.from_path("coref-spanbert-large-2021.03.10.tar.gz")
predictor.predict(document = "Ujjwal likes to eat food. Because of that he cycles every lunch to get food. he is a nice person.")
predictor.coref_resolved(document)
# Out:
# Plugin allennlp_models could not be loaded: No module named 'nltk.translate.meteor_score'
# Downloading:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/665M [00:00<?, ?B/s]
# Some weights of BertModel were not initialized from the model checkpoint at SpanBERT/spanbert-large-cased and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:718: UserWarning: [W094] Model 'en_core_web_sm' (2.2.5) specifies an under-constrained spaCy version requirement: >=2.2.2. This can lead to compatibility problems with older versions, or as new spaCy versions are released, because the model may say it's compatible when it's not. Consider changing the "spacy_version" in your meta.json to a version range, with a lower and upper pin. For example: >=3.0.7,<3.1.0
#   warnings.warn(warn_msg)
# Spacy models 'en_core_web_sm' not found.  Downloading and installing.
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-e2b14c03e2ad> in <module>()
#       1 predictor = Predictor.from_path("coref-spanbert-large-2021.03.10.tar.gz")
#       2 predictor.predict(document = "Ujjwal likes to eat food. Because of that he cycles every lunch to get food. he is a nice person.")
# ----> 3 predictor.coref_resolved(document)
#
# NameError: name 'document' is not defined

# %%
document = "Ujjwal likes to eat food. Because he likes eating, he bikes every lunchtime to get food. he is a nice person."
predictor.predict(document)
predictor.coref_resolved(document)
# Out:
# 'Ujjwal likes to eat food. Because Ujjwal likes eating, Ujjwal bikes every lunchtime to get food. Ujjwal is a nice person.'

# %%
help(predictor.predict)
# Out:
# Help on method predict in module allennlp_models.coref.predictors.coref:
#
# predict(document: str) -> Dict[str, Any] method of allennlp_models.coref.predictors.coref.CorefPredictor instance
#     Predict the coreference clusters in the given document.
#
#     ```
#     {
#     "document": [tokenized document text]
#     "clusters":
#       [
#         [
#           [start_index, end_index],
#           [start_index, end_index]
#         ],
#         [
#           [start_index, end_index],
#           [start_index, end_index],
#           [start_index, end_index],
#         ],
#         ....
#       ]
#     }
#     ```
#
#     # Parameters
#
#     document : `str`
#         A string representation of a document.
#
#     # Returns
#
#     A dictionary representation of the predicted coreference clusters.
